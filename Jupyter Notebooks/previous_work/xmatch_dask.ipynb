# %%
from dask.distributed import Client
import dask.dataframe as dd
import dask.array as da
import dask.bag as db
from dask.dataframe.utils import make_meta
import matplotlib.pyplot as plt 
import numpy as np  
import lsdb
import pandas as pd
from catalog_filtering import create_filter_list, contains_PM

# %%
bandList = ['G','R','I','Z','Y']
class_star = 0.95
spread_model = 0.05
magnitude_error = 0.5
check_flags = True
check_invalid_mags = True
filter_list = create_filter_list(bandList,classStar=class_star,spreadModel=spread_model,magError=magnitude_error,flag=check_flags,invalidMags=check_invalid_mags)
crucialCols = (
    [f'CLASS_STAR_{band}' for band in bandList] + 
    [f'FLAGS_{band}' for band in bandList] + 
    ['RA','DEC','COADD_OBJECT_ID'] + 
    [f'SPREAD_MODEL_{band}' for band in bandList] + 
    [f'WAVG_MAG_PSF_{band}' for band in bandList] + 
    [f'WAVG_MAGERR_PSF_{band}' for band in bandList]
)
catalog = lsdb.read_hipscat('/Volumes/PSC/des_dr2_light/', columns=crucialCols, filters=filter_list)
min_stars = 4
k = 2
collinear_error = 0.2

# %%
# filtered_catalog = catalog.query(query_string)
# xmatch = filtered_catalog.crossmatch(filtered_catalog, n_neighbors=100, radius_arcsec=18, suffixes=['_1', '_2'])
# xmatch_ddf = xmatch._ddf

xmatch = catalog.crossmatch(catalog, n_neighbors=100, radius_arcsec=18, suffixes=['_1', '_2'])
xmatch_ddf = xmatch._ddf
# Out:
# /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/lsdb/dask/crossmatch_catalog_data.py:108: RuntimeWarning: Right catalog does not have a margin cache. Results may be incomplete and/or inaccurate.
#   warnings.warn(

# %%
neighbors = xmatch_ddf.groupby('_hipscat_index')['_dist_arcsec'].count()
neighbors -= 1 #Double counting adjustment
neighbors.name = 'neighbors'
xmatch_ddf = xmatch_ddf.join(neighbors, on='_hipscat_index')
#may need .assign if .join shuffles, shuffling is computationally expensive
xmatch_large_groups = xmatch_ddf.query('neighbors >= 3')

# %%
def distance_to_line(line_vector, PQ):
    return np.abs(np.cross(PQ, line_vector)) / np.linalg.norm(line_vector)

def within_collinear_error(line_vector, PQ, error):
    return (distance_to_line(line_vector, PQ) <= error)

columns_to_keep = (
        [col for col in xmatch_large_groups.columns if col.endswith('_2')]
    )

print(columns_to_keep)
# Out:
# ['CLASS_STAR_G_2', 'CLASS_STAR_R_2', 'CLASS_STAR_I_2', 'CLASS_STAR_Z_2', 'CLASS_STAR_Y_2', 'FLAGS_G_2', 'FLAGS_R_2', 'FLAGS_I_2', 'FLAGS_Z_2', 'FLAGS_Y_2', 'RA_2', 'DEC_2', 'COADD_OBJECT_ID_2', 'SPREAD_MODEL_G_2', 'SPREAD_MODEL_R_2', 'SPREAD_MODEL_I_2', 'SPREAD_MODEL_Z_2', 'SPREAD_MODEL_Y_2', 'WAVG_MAG_PSF_G_2', 'WAVG_MAG_PSF_R_2', 'WAVG_MAG_PSF_I_2', 'WAVG_MAG_PSF_Z_2', 'WAVG_MAG_PSF_Y_2', 'WAVG_MAGERR_PSF_G_2', 'WAVG_MAGERR_PSF_R_2', 'WAVG_MAGERR_PSF_I_2', 'WAVG_MAGERR_PSF_Z_2', 'WAVG_MAGERR_PSF_Y_2']

# %% [markdown]
# # Maximum Error in Projection Distance

# %%
def max_proj_error(group):
    origin_ra, origin_dec = group['RA_1'], group['DEC_1']
    ra2, dec2 = group[["RA_2", "DEC_2"]].to_numpy().T
    
    
    x_vals = (ra2 - origin_ra) * np.cos(np.radians(origin_dec)) * 3600
    y_vals = (dec2 - origin_dec) * 3600
    delta_coords = np.vstack((x_vals, y_vals)).T

    for i in range(len(delta_coords)):
        max_distance = 0
        proj_vector = delta_coords[i]
        if (not np.all(proj_vector)): continue #checks if array = [0 0]

        for k in range(len(delta_coords)):
            test_x, test_y = delta_coords[k]
            if ((test_x == 0) and (test_y == 0)) or (k == i): continue

            curr_distance = distance_to_line(proj_vector, np.array([test_x, test_y]))
            if (curr_distance > max_distance):
                max_distance = curr_distance
    group['max_proj_distance'] = max_distance
    return group[columns_to_keep + ['max_proj_distance']]

# %%
meta = make_meta(xmatch_large_groups[columns_to_keep])
meta['max_proj_distance'] = 0.0
star_groups = xmatch_large_groups.groupby('_hipscat_index').apply(max_proj_error, meta=meta)

# %%
with Client():
    df_1 = star_groups.compute()

df_1 = df_1.reset_index(drop=True, level=0)
df_1 = df_1.drop_duplicates()
df_1
# Out:
#                       CLASS_STAR_G_1  CLASS_STAR_R_1  CLASS_STAR_I_1  \
# _hipscat_index
# 10369096213407465472        0.979719        0.983354        0.985029
# 10369096215483645952        0.424446         0.24536        0.980153
# 10369096217102647296        0.493835        0.979279        0.983372
# 10369096221993205760        0.540009        0.980739        0.982748
# 10369099074845540352        0.343453        0.907556        0.983565
# ...                              ...             ...             ...
# 10374192528239886336        0.966997        0.983858        0.985583
# 10374192551841234944        0.909743        0.946556        0.978222
# 10374223768804392960        0.415803        0.357047        0.388831
# 10374223771832680448        0.978269        0.592493        0.855997
# 10374223776484163584        0.851955        0.969357        0.983956
#
#                       CLASS_STAR_Z_1  CLASS_STAR_Y_1  FLAGS_G_1  FLAGS_R_1  \
# _hipscat_index
# 10369096213407465472        0.983997        0.972619          3          3
# 10369096215483645952         0.83084        0.756592          3          3
# 10369096217102647296        0.971719        0.932593          2          2
# 10369096221993205760        0.932184        0.828752          0          0
# 10369099074845540352        0.989397        0.976505          2          2
# ...                              ...             ...        ...        ...
# 10374192528239886336        0.980288        0.940612          2          2
# 10374192551841234944        0.127373        0.019941          2          2
# 10374223768804392960        0.952667        0.407131          0          0
# 10374223771832680448        0.185873        0.154502          2          2
# 10374223776484163584         0.97229        0.935414          0          0
#
#                       FLAGS_I_1  FLAGS_Z_1  FLAGS_Y_1  ...  WAVG_MAG_PSF_R_1  \
# _hipscat_index                                         ...
# 10369096213407465472          3          3          3  ...         18.999428
# 10369096215483645952          3          3          3  ...         23.590239
# 10369096217102647296          2          2          2  ...         21.433695
# 10369096221993205760          0          0          0  ...         21.916922
# 10369099074845540352          2          2          2  ...         21.821548
# ...                         ...        ...        ...  ...               ...
# 10374192528239886336          2          2          2  ...         21.222857
# 10374192551841234944          2          2          2  ...         21.240795
# 10374223768804392960          0          0          0  ...             -99.0
# 10374223771832680448          2          2          2  ...         22.900162
# 10374223776484163584          0          0          0  ...         20.940075
#
#                       WAVG_MAG_PSF_I_1  WAVG_MAG_PSF_Z_1  WAVG_MAG_PSF_Y_1  \
# _hipscat_index
# 10369096213407465472         18.179893         17.812717         17.724461
# 10369096215483645952         21.964289         21.144239         20.917528
# 10369096217102647296         20.187464         19.639479         19.498238
# 10369096221993205760         21.300776         20.996046         20.899529
# 10369099074845540352         19.601048         18.575277         18.294159
# ...                                ...               ...               ...
# 10374192528239886336         19.944988         19.387199          19.27405
# 10374192551841234944         21.006863         20.982113         20.893478
# 10374223768804392960             -99.0         20.244183             -99.0
# 10374223771832680448         22.867495          22.63636         21.836956
# 10374223776484163584          19.51701         18.913082         18.777506
#
#                       WAVG_MAGERR_PSF_G_1  WAVG_MAGERR_PSF_R_1  \
# _hipscat_index
# 10369096213407465472             0.003647             0.001376
# 10369096215483645952                -99.0             0.065354
# 10369096217102647296              0.02911             0.008052
# 10369096221993205760             0.046124             0.013064
# 10369099074845540352             0.053532              0.01193
# ...                                   ...                  ...
# 10374192528239886336              0.02414             0.008273
# 10374192551841234944             0.010423             0.008106
# 10374223768804392960                -99.0                -99.0
# 10374223771832680448             0.033761             0.036479
# 10374223776484163584             0.020334             0.006574
#
#                       WAVG_MAGERR_PSF_I_1  WAVG_MAGERR_PSF_Z_1  \
# _hipscat_index
# 10369096213407465472             0.001141             0.001096
# 10369096215483645952             0.021689              0.01724
# 10369096217102647296             0.004712             0.004436
# 10369096221993205760             0.011917             0.015186
# 10369099074845540352             0.003003             0.002022
# ...                                   ...                  ...
# 10374192528239886336             0.004059             0.004057
# 10374192551841234944             0.009712             0.014491
# 10374223768804392960                -99.0             0.019065
# 10374223771832680448             0.053451             0.070757
# 10374223776484163584             0.002915             0.002624
#
#                       WAVG_MAGERR_PSF_Y_1  max_proj_distance
# _hipscat_index
# 10369096213407465472             0.003837           9.959932
# 10369096215483645952             0.065455           7.226110
# 10369096217102647296             0.015799           6.432375
# 10369096221993205760             0.065788          11.428107
# 10369099074845540352              0.00614          11.121441
# ...                                   ...                ...
# 10374192528239886336              0.01538           2.005406
# 10374192551841234944             0.066777           2.164921
# 10374223768804392960                -99.0          10.221021
# 10374223771832680448             0.282235          12.846600
# 10374223776484163584             0.009767          14.214721
#
# [251 rows x 29 columns]

# %%
plt.hist(df_1['max_proj_distance'], bins = 50, color='maroon')
plt.xlabel('Max Distance from Projection (arcseconds)')
plt.ylabel('Frequency')
plt.title('Maximum Distance From Line Projection in Each Star Group')
# Out:
# Text(0.5, 1.0, 'Maximum Distance From Line Projection in Each Star Group')

# %% [markdown]
# # Is Collinear to Within Some Margin of Error

# %%
def is_collinear(group, error, min_stars):
    origin_ra, origin_dec = group['RA_1'], group['DEC_1']
    ra2, dec2 = group[["RA_2", "DEC_2"]].to_numpy().T
    is_collinear = False
    
    
    x_vals = (ra2 - origin_ra) * np.cos(np.radians(origin_dec)) * 3600
    y_vals = (dec2 - origin_dec) * 3600
    delta_coords = np.vstack((x_vals, y_vals)).T

    for i in range(len(delta_coords)):
        proj_vector = delta_coords[i]
        found = 2

        if (not np.all(proj_vector)): continue #checks if array = [0 0]

        for k in range(len(delta_coords)):
            test_x, test_y = delta_coords[k]
            if ((test_x == 0) and (test_y == 0)) or (k == i): continue

            if within_collinear_error(proj_vector, np.array([test_x, test_y]), error):
                found += 1
        if (found >= min_stars):
            is_collinear = True
    
    group['is_collinear'] = is_collinear

    return group[columns_to_keep + ['is_collinear']]

# %%
meta = make_meta(xmatch_large_groups[columns_to_keep])
meta['is_collinear'] = 0.0
star_groups = xmatch_large_groups.groupby('_hipscat_index').apply(is_collinear, meta=meta, error=collinear_error, min_stars=min_stars)

# %%
with Client():
    df_2 = star_groups.compute()

df_2 = df_2.reset_index(drop=True, level = 0)
df_2 = df_2.drop_duplicates()
df_2
# Out:
#                       CLASS_STAR_G_1  CLASS_STAR_R_1  CLASS_STAR_I_1  \
# _hipscat_index
# 10369096213407465472        0.979719        0.983354        0.985029
# 10369096215483645952        0.424446         0.24536        0.980153
# 10369096217102647296        0.493835        0.979279        0.983372
# 10369096221993205760        0.540009        0.980739        0.982748
# 10369099074845540352        0.343453        0.907556        0.983565
# ...                              ...             ...             ...
# 10374192528239886336        0.966997        0.983858        0.985583
# 10374192551841234944        0.909743        0.946556        0.978222
# 10374223768804392960        0.415803        0.357047        0.388831
# 10374223771832680448        0.978269        0.592493        0.855997
# 10374223776484163584        0.851955        0.969357        0.983956
#
#                       CLASS_STAR_Z_1  CLASS_STAR_Y_1  FLAGS_G_1  FLAGS_R_1  \
# _hipscat_index
# 10369096213407465472        0.983997        0.972619          3          3
# 10369096215483645952         0.83084        0.756592          3          3
# 10369096217102647296        0.971719        0.932593          2          2
# 10369096221993205760        0.932184        0.828752          0          0
# 10369099074845540352        0.989397        0.976505          2          2
# ...                              ...             ...        ...        ...
# 10374192528239886336        0.980288        0.940612          2          2
# 10374192551841234944        0.127373        0.019941          2          2
# 10374223768804392960        0.952667        0.407131          0          0
# 10374223771832680448        0.185873        0.154502          2          2
# 10374223776484163584         0.97229        0.935414          0          0
#
#                       FLAGS_I_1  FLAGS_Z_1  FLAGS_Y_1  ...  WAVG_MAG_PSF_R_1  \
# _hipscat_index                                         ...
# 10369096213407465472          3          3          3  ...         18.999428
# 10369096215483645952          3          3          3  ...         23.590239
# 10369096217102647296          2          2          2  ...         21.433695
# 10369096221993205760          0          0          0  ...         21.916922
# 10369099074845540352          2          2          2  ...         21.821548
# ...                         ...        ...        ...  ...               ...
# 10374192528239886336          2          2          2  ...         21.222857
# 10374192551841234944          2          2          2  ...         21.240795
# 10374223768804392960          0          0          0  ...             -99.0
# 10374223771832680448          2          2          2  ...         22.900162
# 10374223776484163584          0          0          0  ...         20.940075
#
#                       WAVG_MAG_PSF_I_1  WAVG_MAG_PSF_Z_1  WAVG_MAG_PSF_Y_1  \
# _hipscat_index
# 10369096213407465472         18.179893         17.812717         17.724461
# 10369096215483645952         21.964289         21.144239         20.917528
# 10369096217102647296         20.187464         19.639479         19.498238
# 10369096221993205760         21.300776         20.996046         20.899529
# 10369099074845540352         19.601048         18.575277         18.294159
# ...                                ...               ...               ...
# 10374192528239886336         19.944988         19.387199          19.27405
# 10374192551841234944         21.006863         20.982113         20.893478
# 10374223768804392960             -99.0         20.244183             -99.0
# 10374223771832680448         22.867495          22.63636         21.836956
# 10374223776484163584          19.51701         18.913082         18.777506
#
#                       WAVG_MAGERR_PSF_G_1  WAVG_MAGERR_PSF_R_1  \
# _hipscat_index
# 10369096213407465472             0.003647             0.001376
# 10369096215483645952                -99.0             0.065354
# 10369096217102647296              0.02911             0.008052
# 10369096221993205760             0.046124             0.013064
# 10369099074845540352             0.053532              0.01193
# ...                                   ...                  ...
# 10374192528239886336              0.02414             0.008273
# 10374192551841234944             0.010423             0.008106
# 10374223768804392960                -99.0                -99.0
# 10374223771832680448             0.033761             0.036479
# 10374223776484163584             0.020334             0.006574
#
#                       WAVG_MAGERR_PSF_I_1  WAVG_MAGERR_PSF_Z_1  \
# _hipscat_index
# 10369096213407465472             0.001141             0.001096
# 10369096215483645952             0.021689              0.01724
# 10369096217102647296             0.004712             0.004436
# 10369096221993205760             0.011917             0.015186
# 10369099074845540352             0.003003             0.002022
# ...                                   ...                  ...
# 10374192528239886336             0.004059             0.004057
# 10374192551841234944             0.009712             0.014491
# 10374223768804392960                -99.0             0.019065
# 10374223771832680448             0.053451             0.070757
# 10374223776484163584             0.002915             0.002624
#
#                       WAVG_MAGERR_PSF_Y_1  is_collinear
# _hipscat_index
# 10369096213407465472             0.003837         False
# 10369096215483645952             0.065455         False
# 10369096217102647296             0.015799         False
# 10369096221993205760             0.065788         False
# 10369099074845540352              0.00614         False
# ...                                   ...           ...
# 10374192528239886336              0.01538         False
# 10374192551841234944             0.066777         False
# 10374223768804392960                -99.0         False
# 10374223771832680448             0.282235         False
# 10374223776484163584             0.009767         False
#
# [251 rows x 29 columns]

# %%
filtered_df_2 = df_2.query('is_collinear == True')
filtered_df_2
# Out:
#                       CLASS_STAR_G_1  CLASS_STAR_R_1  CLASS_STAR_I_1  \
# _hipscat_index
# 10370986798804369408        0.005172        0.982307          0.9952
# 10370986798997307392        0.363681        0.980886        0.990194
# 10370986891217469440        0.478828        0.895304        0.977812
# 10370986892068913152         0.19909        0.980313        0.985622
#
#                       CLASS_STAR_Z_1  CLASS_STAR_Y_1  FLAGS_G_1  FLAGS_R_1  \
# _hipscat_index
# 10370986798804369408        0.994617         0.99233          3          3
# 10370986798997307392        0.132001        0.976497          3          3
# 10370986891217469440        0.984843        0.983378          3          3
# 10370986892068913152        0.028624         0.98472          3          3
#
#                       FLAGS_I_1  FLAGS_Z_1  FLAGS_Y_1  ...  WAVG_MAG_PSF_R_1  \
# _hipscat_index                                         ...
# 10370986798804369408          3          3          3  ...         19.362398
# 10370986798997307392          3          3          3  ...         19.425049
# 10370986891217469440          3          3          3  ...             -99.0
# 10370986892068913152          3          3          3  ...         19.385511
#
#                       WAVG_MAG_PSF_I_1  WAVG_MAG_PSF_Z_1  WAVG_MAG_PSF_Y_1  \
# _hipscat_index
# 10370986798804369408         17.116657         15.483732         14.955669
# 10370986798997307392         17.086205             -99.0         14.967874
# 10370986891217469440             -99.0         15.489192             -99.0
# 10370986892068913152         17.113192             -99.0         14.974467
#
#                       WAVG_MAGERR_PSF_G_1  WAVG_MAGERR_PSF_R_1  \
# _hipscat_index
# 10370986798804369408              0.05949             0.003771
# 10370986798997307392             0.044888             0.004398
# 10370986891217469440                -99.0                -99.0
# 10370986892068913152             0.044052             0.004155
#
#                       WAVG_MAGERR_PSF_I_1  WAVG_MAGERR_PSF_Z_1  \
# _hipscat_index
# 10370986798804369408             0.001143               0.0008
# 10370986798997307392             0.001177                -99.0
# 10370986891217469440                -99.0             0.001013
# 10370986892068913152             0.000972                -99.0
#
#                       WAVG_MAGERR_PSF_Y_1  is_collinear
# _hipscat_index
# 10370986798804369408             0.001202          True
# 10370986798997307392             0.001725          True
# 10370986891217469440                -99.0          True
# 10370986892068913152             0.000905          True
#
# [4 rows x 29 columns]

# %%
plt.scatter(filtered_df_2['RA_1'] * 3600, filtered_df_2['DEC_1'] * 3600)
plt.xlabel('Right-Ascention (arcsecs)')
plt.ylabel('Declination (arcsecs)')
plt.title('Possible PM Stars Following Star Filtering and Line Projection (DASK)')
# Out:
# Text(0.5, 1.0, 'Possible PM Stars Following Star Filtering and Line Projection (DASK)')

# %%
def kth_star_min_distance(group, k):
    origin_ra, origin_dec = group['RA_1'], group['DEC_1']
    ra2, dec2 = group[["RA_2", "DEC_2"]].to_numpy().T
    
    x_vals = (ra2 - origin_ra) * np.cos(np.radians(origin_dec)) * 3600
    y_vals = (dec2 - origin_dec) * 3600
    delta_coords = np.vstack((x_vals, y_vals)).T

    kth_distances = [None] * len(delta_coords)

    for i in range(len(delta_coords)):
        proj_vector = delta_coords[i]
        distances = []

        if np.all(proj_vector == 0): continue #ensures vector points to a point that is not the origin

        for j in range(len(delta_coords)):
            if np.all(delta_coords[j] == 0) or (j == i): continue
            
            distances.append(distance_to_line(proj_vector, delta_coords[j]))

        kth_distances[i] = sorted(distances)[k]
    
    group['kth_min_proj_error'] = kth_distances

    return group[columns_to_keep + ['kth_min_proj_error']]

# %%
meta = make_meta(xmatch_large_groups[columns_to_keep])
meta['kth_min_proj_error'] = 0.0
star_groups = xmatch_large_groups.groupby('_hipscat_index').apply(kth_star_min_distance, meta=meta, k=k-1)

# %%
with Client(n_workers=1) as client:
    df_3 = star_groups.compute()
# Out:
# <Client: 'tcp://127.0.0.1:53544' processes=1 threads=8, memory=8.00 GiB>
# Task exception was never retrieved
# future: <Task finished name='Task-747' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1090' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1730' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-820' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-822' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1048' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-881' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-699' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-662' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-724' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1347' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-768' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-602' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-573' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-603' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-648' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-683' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-595' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-626' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-689' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-624' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-569' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1407' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1366' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1328' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1244' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1662' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1628' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1699' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1704' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1715' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1678' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1653' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1668' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1721' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1697' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1670' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1694' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1517' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1742' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1744' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-166' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-163' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-165' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-164' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1335' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1283' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1287' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1310' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1323' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1319' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1314' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1306' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1340' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1728' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1725' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1737' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1733' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1739' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1731' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1734' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1735' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1732' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1743' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1741' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1740' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1729' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1727' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1738' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1736' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-288' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-561' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-401' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-501' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-307' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-551' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-263' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-384' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-423' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-440' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1172' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1085' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1080' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1105' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1122' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1145' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1121' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1079' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1125' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1120' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1083' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1084' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1092' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1118' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1116' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1176' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1107' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1119' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1111' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1130' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1097' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1136' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1135' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1178' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1155' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1150' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1128' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1099' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
# ...
# Task exception was never retrieved
# future: <Task finished name='Task-1618' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1540' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1635' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1533' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1702' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1625' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1590' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1686' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1658' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1470' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1493' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1684' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1661' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1486' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1654' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1677' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1465' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1705' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1560' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1606' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1588' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1674' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1585' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1529' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1459' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1695' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1647' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1507' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-1717' coro=<Client._gather.<locals>.wait() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py:2278> exception=AllExit()>
# Traceback (most recent call last):
#   File "/Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/client.py", line 2287, in wait
#     raise AllExit()
# distributed.client.AllExit
# 2024-07-31 15:01:42,472 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1376))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,703 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1377))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,703 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1373))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,703 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1375))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,703 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1374))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,703 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1379))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,704 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1378))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:42,704 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute(('read_parquet_file_to_pandas-f08c6fa3cfdda7c0c3957f1ee2e0f444', 1372))" coro=<Worker.execute() done, defined at /Users/johnpassos/Documents/LSDB/venv/lib/python3.11/site-packages/distributed/worker_state_machine.py:3615>> ended with CancelledError
# 2024-07-31 15:01:43,946 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing

# %%
df_3 = df_3.reset_index(drop=True, level = 0)


df_3
# Out:
#                       CLASS_STAR_G_2  CLASS_STAR_R_2  CLASS_STAR_I_2  \
# _hipscat_index
# 10369096213407465472        0.979719        0.983354        0.985029
# 10369096213407465472        0.424446         0.24536        0.980153
# 10369096213407465472        0.540009        0.980739        0.982748
# 10369096213407465472        0.493835        0.979279        0.983372
# 10369096215483645952        0.424446         0.24536        0.980153
# ...                              ...             ...             ...
# 10374223771832680448        0.851955        0.969357        0.983956
# 10374223776484163584        0.851955        0.969357        0.983956
# 10374223776484163584        0.415803        0.357047        0.388831
# 10374223776484163584        0.978269        0.592493        0.855997
# 10374223776484163584        0.989798        0.985666        0.984101
#
#                       CLASS_STAR_Z_2  CLASS_STAR_Y_2  FLAGS_G_2  FLAGS_R_2  \
# _hipscat_index
# 10369096213407465472        0.983997        0.972619          3          3
# 10369096213407465472         0.83084        0.756592          3          3
# 10369096213407465472        0.932184        0.828752          0          0
# 10369096213407465472        0.971719        0.932593          2          2
# 10369096215483645952         0.83084        0.756592          3          3
# ...                              ...             ...        ...        ...
# 10374223771832680448         0.97229        0.935414          0          0
# 10374223776484163584         0.97229        0.935414          0          0
# 10374223776484163584        0.952667        0.407131          0          0
# 10374223776484163584        0.185873        0.154502          2          2
# 10374223776484163584        0.985304         0.95271          0          0
#
#                       FLAGS_I_2  FLAGS_Z_2  FLAGS_Y_2  ...  WAVG_MAG_PSF_R_2  \
# _hipscat_index                                         ...
# 10369096213407465472          3          3          3  ...         18.999428
# 10369096213407465472          3          3          3  ...         23.590239
# 10369096213407465472          0          0          0  ...         21.916922
# 10369096213407465472          2          2          2  ...         21.433695
# 10369096215483645952          3          3          3  ...         23.590239
# ...                         ...        ...        ...  ...               ...
# 10374223771832680448          0          0          0  ...         20.940075
# 10374223776484163584          0          0          0  ...         20.940075
# 10374223776484163584          0          0          0  ...             -99.0
# 10374223776484163584          2          2          2  ...         22.900162
# 10374223776484163584          0          0          0  ...         18.201614
#
#                       WAVG_MAG_PSF_I_2  WAVG_MAG_PSF_Z_2  WAVG_MAG_PSF_Y_2  \
# _hipscat_index
# 10369096213407465472         18.179893         17.812717         17.724461
# 10369096213407465472         21.964289         21.144239         20.917528
# 10369096213407465472         21.300776         20.996046         20.899529
# 10369096213407465472         20.187464         19.639479         19.498238
# 10369096215483645952         21.964289         21.144239         20.917528
# ...                                ...               ...               ...
# 10374223771832680448          19.51701         18.913082         18.777506
# 10374223776484163584          19.51701         18.913082         18.777506
# 10374223776484163584             -99.0         20.244183             -99.0
# 10374223776484163584         22.867495          22.63636         21.836956
# 10374223776484163584          18.08214         18.032475         18.054348
#
#                       WAVG_MAGERR_PSF_G_2  WAVG_MAGERR_PSF_R_2  \
# _hipscat_index
# 10369096213407465472             0.003647             0.001376
# 10369096213407465472                -99.0             0.065354
# 10369096213407465472             0.046124             0.013064
# 10369096213407465472              0.02911             0.008052
# 10369096215483645952                -99.0             0.065354
# ...                                   ...                  ...
# 10374223771832680448             0.020334             0.006574
# 10374223776484163584             0.020334             0.006574
# 10374223776484163584                -99.0                -99.0
# 10374223776484163584             0.033761             0.036479
# 10374223776484163584              0.00134             0.001027
#
#                       WAVG_MAGERR_PSF_I_2  WAVG_MAGERR_PSF_Z_2  \
# _hipscat_index
# 10369096213407465472             0.001141             0.001096
# 10369096213407465472             0.021689              0.01724
# 10369096213407465472             0.011917             0.015186
# 10369096213407465472             0.004712             0.004436
# 10369096215483645952             0.021689              0.01724
# ...                                   ...                  ...
# 10374223771832680448             0.002915             0.002624
# 10374223776484163584             0.002915             0.002624
# 10374223776484163584                -99.0             0.019065
# 10374223776484163584             0.053451             0.070757
# 10374223776484163584              0.00109             0.001389
#
#                       WAVG_MAGERR_PSF_Y_2  kth_min_proj_error
# _hipscat_index
# 10369096213407465472             0.003837                 NaN
# 10369096213407465472             0.065455           14.168895
# 10369096213407465472             0.065788           11.428086
# 10369096213407465472             0.015799            9.959932
# 10369096215483645952             0.065455                 NaN
# ...                                   ...                 ...
# 10374223771832680448             0.009767           12.846600
# 10374223776484163584             0.009767                 NaN
# 10374223776484163584                -99.0           13.920940
# 10374223776484163584             0.282235           14.876678
# 10374223776484163584             0.005392           14.214721
#
# [1040 rows x 29 columns]

# %%
plt.hist(df_3['kth_min_proj_error'], bins=75, color = 'green')
plt.title('Kth Minimum Distance From Projection in Each Star Group')
plt.ylabel('Group Count')
plt.xlabel('Kth Minimum Distance (arcseconds)')
# Out:
# Text(0.5, 0, 'Kth Minimum Distance (arcseconds)')
